# %% [markdown]
# ## Maximum Product of Two Elements in an Array
# https://leetcode.com/problems/maximum-product-of-two-elements-in-an-array/description/

# %%
def maxproduct(nums):
    nums.sort(reverse=True)
    return (nums[0]-1)*(nums[1]-1)

# %%
nums = [3,4,5,2]
maxproduct(nums)
# Out:
# 12

# %%
nums = [1,5,4,5]
maxproduct(nums)
# Out:
# 16

# %%
nums = [3,7]
maxproduct(nums)
# Out:
# 12

# %% [markdown]
# ## Count Number of Teams
# https://leetcode.com/problems/count-number-of-teams/description/

# %%
def numTeams(rating):
    n = len(rating)
    count = 0

    for j in range(n):
        left_smaller = left_greater = 0
        right_smaller = right_greater = 0

        for i in range(j):
            if rating[i] < rating[j]:
                left_smaller += 1
            elif rating[i] > rating[j]:
                left_greater += 1

        for k in range(j + 1, n):
            if rating[k] < rating[j]:
                right_smaller += 1
            elif rating[k] > rating[j]:
                right_greater += 1

        count += left_smaller * right_greater
        count += left_greater * right_smaller

    return count


print(numTeams([2,5,3,4,1]))  

print(numTeams([2,1,3]))     

print(numTeams([1,2,3,4]))
# Out:
# 3
# 0
# 4

# %% [markdown]
# ## Number of Students Doing Homework at a Given Time
# https://leetcode.com/problems/number-of-students-doing-homework-at-a-given-time/submissions/1859044767/

# %%
starttime = [1,2,3]
endtime = [3,2,7]
querytime = 4
count = 0
for i in range(len(starttime)):
    if starttime[i]<=querytime<=endtime[i]:
        count+= 1
print(count)
# Out:
# 1

# %% [markdown]
# ## Number of Steps to Reduce a Number to Zero
# https://leetcode.com/problems/number-of-steps-to-reduce-a-number-to-zero/description/

# %%
num = 8
step = 0
while num > 0:
    if num%2 == 0:
        num = num//2
        step += 1
    else:
        num -= 1
        step += 1
print(step)
# Out:
# 4

# %% [markdown]
# ## Counting Bits
# https://leetcode.com/problems/counting-bits/description/

# %%
def countBits(n):
    res = [0] * (n + 1)
    for i in range(1, n + 1):
        res[i] = res[i // 2] + (i % 2)
    return res

print(countBits(5))
# Out:
# [0, 1, 1, 2, 1, 2]
